# %%
import numpy as np
x = np.arange(1, 10,1)
y = np.random.randint(0,2,9)
print(x)
print(y)
# Out:
# [1 2 3 4 5 6 7 8 9]
# [0 1 0 0 1 1 1 1 1]

# %%
def step_function(z):
    return 1 if z >= 0 else 0

# %%
def sigmoid(z):
    return 1 / (1 + np.exp(-z))

# %%
# perceptron from scratch
def perceptron(x, y):
    x = np.insert(x, 0, 1, axis=1)  # add bias term
    weights = np.ones(x.shape[1])  # initialize weights randomly

    lr = 0.1  # learning rate
    for i in range(100):  # number of epochs
        for j in range(len(x)):
            j = np.random.randint(0,x.shape[0])
            # j = np.random.randint(0, 100)
            # y = mx + c
            y_hat = step(np.dot(x[j], weights))
            weights = weights + lr * (y[j] - y_hat) * x[j]
        return weights

# %%
def step():
    pass

# %%
def sigmoid():
    pass
