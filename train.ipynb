# %%
import numpy as np
import pandas as pd
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt

# %%
input,labels = make_regression(n_samples=100, n_features=1, noise=0.1, n_targets = 1)

# %%
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt

X, y = make_regression(n_samples=100, n_features=1, noise=0.1, n_targets=1)

plt.scatter(X, y)
plt.show()
